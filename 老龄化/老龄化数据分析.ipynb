# %%
# %pylab
# %matplotlib inline 
import pandas as pd
import pyecharts
import seaborn as sns
from matplotlib import patches
from scipy.spatial import ConvexHull
import warnings; warnings.simplefilter('ignore')
sns.set(style='white')
mpl.rcParams['font.sans-serif'] = ['SimHei'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
# df = pd.read_csv('./data/2018各省市年龄与抚养比.csv').drop('Unnamed: 0', axis=1)
# df.to_csv('./data/2018各省市年龄与抚养比.csv', index=False)

# %%
AR = pd.read_csv('./data/2018各省市年龄与抚养比.csv')
GDP = pd.read_csv('./data/2018各省市生产总值.csv')
MT = pd.read_csv('./data/med.csv') # 医疗水平
ED = pd.read_csv('./data/教育指数.csv') # 教育水平
UAR = pd.read_csv('./data/2010-2018各省市城市人口比重.csv')
SEX = pd.read_csv('./data/2018各省市性别比例.csv')
IN = pd.read_csv('./data/2018各省市工业化水平.csv')
AS = pd.read_csv('./data/2018年龄段性别比例.csv')
MI = pd.read_csv('./data/2009—2014年全国各地区人口迁入率统计值.csv')

# %%
MI
# Out:
#      地区  2009  2010  2011  2012  2013  2014
# 0    全国   8.6   5.3  19.5  19.2  18.9  19.0
# 1    北京  45.5  29.9  56.6  50.1  52.7  59.6
# 2    天津  12.3  10.6  25.7  24.0  23.7  23.7
# 3    河北   5.7   3.1  10.7   7.9   9.3   9.2
# 4    山西   6.7   7.9  15.1  17.8  20.6  18.8
# 5    内蒙  11.9  12.1  31.6  31.2  27.2  28.9
# 6    辽宁   6.9   6.7  20.3  25.5  22.2  18.6
# 7    吉林   5.6   5.3  17.7  18.0  14.8  15.0
# 8   黑龙江   9.3   5.3  14.8  13.5  15.4  17.9
# 9    上海  29.3  48.2  64.4  62.9  60.1  61.9
# 10   江苏  11.3  11.2  23.4  20.1  18.0  21.9
# 11   浙江  16.4  18.9  39.2  38.4  40.3  39.2
# 12   安徽   4.2   2.6  13.3  14.3  12.7  15.2
# 13   福建  17.8   9.9  38.1  34.6  36.6  38.8
# 14   江西   4.7   2.6  11.7   8.5   8.9   8.9
# 15   山东   4.0   2.5  11.8  12.8  10.7  10.9
# 16   河南   1.7   1.6  12.2   9.0   8.3   8.7
# 17   湖北   4.6   4.1  13.9  16.9  20.6  18.0
# 18   湖南   2.7   2.0   9.6   7.8   8.9  10.9
# 19   广东  27.6   8.7  30.0  34.6  34.2  29.8
# 20   广西   3.4   3.0  13.8  10.7  12.7  14.9
# 21   海南   7.0   7.0  21.5  19.3  18.4  22.1
# 22   重庆   7.7   3.6  21.4  19.1  20.4  23.2
# 23   四川   5.4   3.3  15.9  17.9  14.3  14.7
# 24   贵州   4.8   4.2  16.4  14.3  16.2  17.5
# 25   云南   4.4   4.4  15.8  15.6  12.1   9.6
# 26   西藏   0.1   2.8   7.4   0.5   6.3   1.4
# 27   陕西   5.5   3.6  13.2  14.0  15.8  11.5
# 28   甘肃   1.9   2.3   9.1  10.6   9.2   8.3
# 29   青海   8.1   4.7  19.9  16.6  15.6  18.8
# 30   宁夏   8.4  12.3  23.3  23.9  22.7  21.4
# 31   新疆   4.1   8.1  22.3  19.9  18.5  17.7

# %%
for df in [AR, GDP, MT, ED, UAR, SEX, IN]:
    df['地区'] = df['地区'].apply(lambda city: ''.join(str(city).split('  ')).strip())
#     df.set_index('地区')

# %%
for df in [AR, GDP, MT, ED, UAR, SEX, IN]:
    display(df.head(2))
# Out:
#    地区      人口数   0-14岁  15-64岁     65岁及以上   总抚养比  少年儿童抚养比  老年人口抚养比     老龄化比率
# 0  全国  1144648  192963  815039  136645.26  40.44    23.68    16.77  0.119378
# 1  北京    17673    1850   13834    1988.79  27.75    13.37    14.38  0.112533
#    地区      生产总值  总值第一产业   总值第二产业    总值第三产业       人均地区生产总值  人均总值第一产业  人均总值第二产业  \
# 0  北京  30319.98  118.69  5647.65  24553.64  140211.241878      0.39     18.63
# 1  天津  18809.64  172.71  7609.81  11027.12  120710.801930      0.92     40.46
#
#    人均总值第三产业  地区生产总值指数  第一产业指数  第二产业指数  第三产业指数  人均地区生产总值.1
# 0     80.98     106.6    97.7   104.2   107.3  107.093618
# 1     58.62     103.6   100.1   101.0   105.9  103.710112
#    地区  人口集聚度  基层医疗机构数(张)  卫生机构集聚度  卫生机构比值    床位数(张)  床位数集聚度  床位数比值
# 0  江苏  5.464     29099.0    2.967    0.54   77546.0   5.150   0.95
# 1  山东  4.533     72904.0    4.960    1.11  115017.0   5.096   1.14
#    地区   规模度    投入度    质量度    信息度   公平度    贡献度   发展指数
# 0  北京  3.85  10.00  10.00  10.00  9.07  10.00  10.00
# 1  天津  3.94   5.49   6.92   5.19  6.97   2.03   5.63
#    地区       2010   2011   2012   2013   2014  2015   2016   2017   2018
# 0  全国  49.950000  51.27  52.57  53.73  54.77  56.1  57.35  58.52  59.58
# 1  北京  85.959455  86.20  86.20  86.30  86.35  86.5  86.50  86.50  86.50
#    地区       合计       男       女
# 0  全国  1144648  585299  559349
# 1  北京    17673    8781    8892
#    地区  工业化综合指数
# 0  北京      100
# 1  天津      100

# %%
res = AR.iloc[1:, 0]
for df in [AR[['地区', '人口数', '老年人口抚养比', '老龄化比率']], 
           GDP[['地区', '生产总值', '人均地区生产总值']], 
           MT[['地区', '卫生机构集聚度']], 
           ED[['地区', '发展指数']], 
           UAR[['地区', '2018']], 
           SEX[['地区', '男','女']],
          IN[['地区', '工业化综合指数']]]:
    res = pd.merge(res, df, how='left', on='地区')
res.columns = ['地区', '总人口数', '老年人口抚养比', '老龄化比率', '生产总值', '人均地区生产总值', '医疗条件指数',
       '教育条件指数', '城镇人口比重', '男性人数', '女性人数', '工业化综合指数']
res.fillna(res['医疗条件指数'].max(), inplace=True)
res.head()
# Out:
#     地区   总人口数  老年人口抚养比     老龄化比率      生产总值       人均地区生产总值  医疗条件指数  教育条件指数  \
# 0   北京  17673    14.38  0.112533  30319.98  140211.241878   4.960   10.00
# 1   天津  12794    13.85  0.109182  18809.64  120710.801930   4.960    5.63
# 2   河北  61907    18.43  0.126871  36010.27   47772.220682   4.237    5.33
# 3   山西  30481    13.94  0.103259  16818.11   45328.000000   2.697    4.86
# 4  内蒙古  20781    12.81  0.098484  17289.22   68302.000000   0.200    4.70
#
#    城镇人口比重   男性人数   女性人数  工业化综合指数
# 0   86.50   8781   8892      100
# 1   83.15   6863   5931      100
# 2   56.43  31210  30697       70
# 3   58.41  15593  14888       57
# 4   62.71  10608  10174       75

# %%
'''聚类分析, 根据四个指标看出分出四类最合适'''
from sklearn.cluster import KMeans

data = res[['人均地区生产总值', '医疗条件指数','教育条件指数','工业化综合指数']]

SSE = []  # 存放每次结果的误差平方和
for k in range(1,9):
    estimator = KMeans(n_clusters=k)  # 构造聚类器
    estimator.fit(data)
    SSE.append(estimator.inertia_)
X = range(1,9)
plt.xlabel('k')
plt.ylabel('SSE')
plt.plot(X,SSE,'o-')

# %%
# 聚类可视化
estimator = KMeans(n_clusters=4)  # 构造聚类器
y_pred = estimator.fit_predict(data)

categories = set(y_pred)
colors = [plt.cm.tab10(i/float(len(categories))) for i in range(len(categories))]
plt.figure(figsize=(10, 8), dpi= 80, facecolor='w', edgecolor='k')    
sns.scatterplot(x= '医疗条件指数', y='人均地区生产总值', 
            hue=y_pred, palette="Set2", s=100, alpha=0.5,
            data=data)

# for i, category in enumerate(categories):
#     plt.scatter('医疗条件指数', '人均地区生产总值',  data=data[y_pred == categories],
#                 cmap=colors[i], label=str(category), edgecolors='black', linewidths=.5)

def encircle(x,y, ax=None, **kw):
    if not ax: ax=plt.gca()
    p = np.c_[x,y]
    hull = ConvexHull(p)
    poly = plt.Polygon(p[hull.vertices,:], **kw)
    ax.add_patch(poly)

    

fc = ['red', 'gold', 'blue', 'green']    
def draw_circle(index):
    midwest_encircle_data = data[y_pred == index]                         
    encircle(midwest_encircle_data['医疗条件指数'], midwest_encircle_data['人均地区生产总值'], ec="k", fc=fc[index], alpha=0.1)
    encircle(midwest_encircle_data['医疗条件指数'], midwest_encircle_data['人均地区生产总值'], ec="firebrick", fc="none", linewidth=1.5)

    
# for index in categories:
#     draw_circle(index)
draw_circle(0) 

plt.gca().set(xlim=(0.0, 5.2), ylim=(2000, 145000),
              xlabel='医疗条件指数', ylabel='人均地区生产总值')


plt.xticks(fontsize=12); plt.yticks(fontsize=12)
plt.title("聚类结果", fontsize=22)
plt.legend(fontsize=12)    
plt.show()

# %%
res.corr()['老龄化比率'].to_frame()
# Out:
#              老龄化比率
# 总人口数      0.432813
# 老年人口抚养比   0.976877
# 老龄化比率     1.000000
# 生产总值      0.415584
# 人均地区生产总值  0.286122
# 医疗条件指数    0.560783
# 教育条件指数    0.403642
# 城镇人口比重    0.406100
# 男性人数      0.410160
# 女性人数      0.455762
# 工业化综合指数   0.492345

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(res.corr(), cmap='rainbow')
# Out:
# <AxesSubplot:>

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie
from pyecharts.faker import Faker

value = SEX.iloc[0].values[2:]
value_sum = sum(value)
value = [round(v / value_sum * 10000 / 100, 2) for v in value]
label = ['男', '女']

p = (
    Pie()
    .add("", [list(z) for z in zip(label, value)])
    .set_colors(["blue", "red"])
    .set_global_opts(title_opts=opts.TitleOpts(title="男女分布饼图"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    
)
p.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="bca2cb7ed6e743b7931f52cb8cee458c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_bca2cb7ed6e743b7931f52cb8cee458c = echarts.init(
#                     document.getElementById('bca2cb7ed6e743b7931f52cb8cee458c'), 'white', {renderer: 'canvas'});
#                 var option_bca2cb7ed6e743b7931f52cb8cee458c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "blue",
#         "red"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u7537",
#                     "value": 51.13
#                 },
#                 {
#                     "name": "\u5973",
#                     "value": 48.87
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7537",
#                 "\u5973"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u7537\u5973\u5206\u5e03\u997c\u56fe"
#         }
#     ]
# };
#                 chart_bca2cb7ed6e743b7931f52cb8cee458c.setOption(option_bca2cb7ed6e743b7931f52cb8cee458c);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie
from pyecharts.faker import Faker

value = AR.loc[AR['地区']  == '全国', [ '0-14岁', '15-64岁', '65岁及以上']].values.ravel()
value_sum = sum(value)
value = [round(v / value_sum * 10000 / 100, 2) for v in value]
label = [ '0-14岁', '15-64岁', '65岁及以上']

p = (
    Pie()
    .add("", [list(z) for z in zip(label, value)])
    .set_colors(["yellow", "red", "pink"])
    .set_global_opts(title_opts=opts.TitleOpts(title="年龄段分布饼图"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    
)
p.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="1c5e44271da043fcaee2736b003f037c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_1c5e44271da043fcaee2736b003f037c = echarts.init(
#                     document.getElementById('1c5e44271da043fcaee2736b003f037c'), 'white', {renderer: 'canvas'});
#                 var option_1c5e44271da043fcaee2736b003f037c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "yellow",
#         "red",
#         "pink"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "0-14\u5c81",
#                     "value": 16.86
#                 },
#                 {
#                     "name": "15-64\u5c81",
#                     "value": 71.2
#                 },
#                 {
#                     "name": "65\u5c81\u53ca\u4ee5\u4e0a",
#                     "value": 11.94
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "0-14\u5c81",
#                 "15-64\u5c81",
#                 "65\u5c81\u53ca\u4ee5\u4e0a"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5e74\u9f84\u6bb5\u5206\u5e03\u997c\u56fe"
#         }
#     ]
# };
#                 chart_1c5e44271da043fcaee2736b003f037c.setOption(option_1c5e44271da043fcaee2736b003f037c);
#         });
#     </script>

# %%
SEX.head()
# Out:
#    地区       合计       男       女
# 0  全国  1144648  585299  559349
# 1  北京    17673    8781    8892
# 2  天津    12794    6863    5931
# 3  河北    61907   31210   30697
# 4  山西    30481   15593   14888

# %%
data = AR.iloc[0:, [0, 2, 3, 4]]
data = pd.merge(data, SEX.iloc[0:, [0, 2, 3]], on='地区')
data = data.iloc[0, 1:]
M = (data[:-2]  * 1.05 // 2).to_frame().reset_index()
F = (data[:-2] * 0.95 // 2 ).to_frame().reset_index()

data = pd.merge(M, F, on='index')
data.columns = ['年龄段','男', '女']
data
# Out:
#       年龄段       男       女
# 0   0-14岁  101305   91657
# 1  15-64岁  427895  387143
# 2  65岁及以上   71738   64906

# %%
plt.figure(figsize=(8, 6))
X = np.array([1, 2, 3])
plt.subplot(121)
plt.bar(data['年龄段'], data['男'], alpha=0.5, width=0.35, label='男')
plt.subplot(122)
plt.bar(data['年龄段'], data['女'], alpha=0.5, width=0.35, label='女')
plt.legend()
plt.ylabel('人数')
plt.xlabel('年龄段')
plt.show()

# %%
data = AS.iloc[1:]
plt.figure(figsize=(10, 8))
ax = plt.subplot(121)
plt.barh(data['年龄段'], data['男'], alpha=0.5, label='男')
ax.invert_xaxis()
plt.yticks([])
plt.legend()
plt.xlabel('人数')

plt.subplot(122)
plt.barh(data['年龄段'], data['女'], alpha=0.5, label='女', color='red')
plt.legend()
# plt.ylabel('人数')

plt.xlabel('人数')

plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
y = MinMaxScaler().fit_transform(res['老龄化比率'].values.reshape(-1, 1))*225
region = res['地区']

from pyecharts import options as opts
from pyecharts.charts import Map
c = (
    Map()
    .add("老龄化程度", [list(z) for z in zip(region, y.ravel())], "china")
    .set_global_opts(title_opts=opts.TitleOpts(title="老龄化程度"),
    visualmap_opts=opts.VisualMapOpts(max_=225))
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="ce4faf73f30b4ec9ab81d543217a436a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_ce4faf73f30b4ec9ab81d543217a436a = echarts.init(
#                     document.getElementById('ce4faf73f30b4ec9ab81d543217a436a'), 'white', {renderer: 'canvas'});
#                 var option_ce4faf73f30b4ec9ab81d543217a436a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u8001\u9f84\u5316\u7a0b\u5ea6",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 132.1150508910626
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 124.15476813141456
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 166.18396225625136
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 110.0807223310882
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 98.73545620913914
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 220.55549171340118
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 158.68963405068786
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 154.9350695314441
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 220.0016714987651
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 204.4192129733781
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 173.2703430213345
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 178.41013009101582
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 90.13517655128707
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 96.03322073564112
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 225.0
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 127.4046544557823
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 161.55648957486335
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 161.41446045891482
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 61.068945647724064
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 102.95236521669666
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 59.74664524302905
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 208.5627912153959
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 220.8627720151161
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 134.20518162688617
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 92.24866247369435
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 0.0
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 129.93315028267878
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 133.61325678562773
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 45.149016035634915
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 78.35763258438092
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 34.81471173514847
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8001\u9f84\u5316\u7a0b\u5ea6"
#             ],
#             "selected": {
#                 "\u8001\u9f84\u5316\u7a0b\u5ea6": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u8001\u9f84\u5316\u7a0b\u5ea6"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 225,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140
#     }
# };
#                 chart_ce4faf73f30b4ec9ab81d543217a436a.setOption(option_ce4faf73f30b4ec9ab81d543217a436a);
#         });
#     </script>

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
region = GDP['地区']
gdp = MinMaxScaler().fit_transform(GDP['人均地区生产总值'].values.reshape(-1, 1))*225

from pyecharts import options as opts
from pyecharts.charts import Map
c = (
    Map()
    .add("GDP", [list(z) for z in zip(region, gdp.ravel())], "china")
    .set_global_opts(title_opts=opts.TitleOpts(title="GDP"),
    visualmap_opts=opts.VisualMapOpts(max_=225))
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="a2b53cd974dc4145914f74a88dbc2b22" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_a2b53cd974dc4145914f74a88dbc2b22 = echarts.init(
#                     document.getElementById('a2b53cd974dc4145914f74a88dbc2b22'), 'white', {renderer: 'canvas'});
#                 var option_a2b53cd974dc4145914f74a88dbc2b22 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "GDP",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 225.0
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 184.70062654721852
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 33.966636304839305
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 28.91543939227006
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 76.39323005602185
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 55.118773422711726
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 50.166005807737776
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 24.671505958733352
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 214.19331195116288
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 173.2467821712965
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 139.09641870419296
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 33.84149150878365
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 123.70827507944678
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 33.26756122347422
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 92.85413326049883
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 38.885120153770465
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 72.90835015333522
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 44.66408650854605
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 113.81913712142384
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 20.98214984978973
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 42.6113214284461
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 71.49691330538208
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 36.26251094511868
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 20.474653913585467
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 11.986534935778572
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 24.9269247243393
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 66.42292471914607
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 0.0
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 33.7955887303443
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 47.03149508433782
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 37.48499528362804
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "GDP"
#             ],
#             "selected": {
#                 "GDP": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "GDP"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 225,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140
#     }
# };
#                 chart_a2b53cd974dc4145914f74a88dbc2b22.setOption(option_a2b53cd974dc4145914f74a88dbc2b22);
#         });
#     </script>

# %%
'''确缺失四大市'''
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
region = MT['地区']
mt = MinMaxScaler().fit_transform(MT[['卫生机构集聚度', '床位数集聚度']].sum(axis=1).values.reshape(-1, 1))*225

from pyecharts import options as opts
from pyecharts.charts import Map
c = (
    Map()
    .add("医疗条件", [list(z) for z in zip(region, mt.ravel())], "china")
    .set_global_opts(title_opts=opts.TitleOpts(title="医疗条件"),
    visualmap_opts=opts.VisualMapOpts(max_=225))
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="b5b32c87c7a149c8b00e9f43061d837e" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_b5b32c87c7a149c8b00e9f43061d837e = echarts.init(
#                     document.getElementById('b5b32c87c7a149c8b00e9f43061d837e'), 'white', {renderer: 'canvas'});
#                 var option_b5b32c87c7a149c8b00e9f43061d837e = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u533b\u7597\u6761\u4ef6",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 181.28944995491435
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 225.0
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 114.6528403967538
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 196.19026149684393
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 104.30568079350765
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 100.36068530207393
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 156.71776375112714
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 141.3435527502254
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 114.76555455365192
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 90.8025247971145
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 91.81695220919748
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 98.331830477908
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 60.978358881875565
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 95.51397655545536
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 71.57348963029756
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 70.80703336339045
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 64.49504057709647
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 77.97565374211
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 40.103697024346246
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 19.837691614066724
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 32.596934174932365
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 17.921550946798913
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 21.370604147880968
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 6.041478809738503
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 3.5843101893597837
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 1.3525698827772767
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 0.0
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u533b\u7597\u6761\u4ef6"
#             ],
#             "selected": {
#                 "\u533b\u7597\u6761\u4ef6": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u533b\u7597\u6761\u4ef6"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 225,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140
#     }
# };
#                 chart_b5b32c87c7a149c8b00e9f43061d837e.setOption(option_b5b32c87c7a149c8b00e9f43061d837e);
#         });
#     </script>

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
region = ED['地区']
edu = MinMaxScaler().fit_transform(ED[['发展指数']].values.reshape(-1, 1))*225

from pyecharts import options as opts
from pyecharts.charts import Map
c = (
    Map()
    .add("教育水平", [list(z) for z in zip(region, edu.ravel())], "china")
    .set_global_opts(title_opts=opts.TitleOpts(title="教育水平"),
    visualmap_opts=opts.VisualMapOpts(max_=225))
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="ad7c426ceac0469c9c8f8e7b4552288d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_ad7c426ceac0469c9c8f8e7b4552288d = echarts.init(
#                     document.getElementById('ad7c426ceac0469c9c8f8e7b4552288d'), 'white', {renderer: 'canvas'});
#                 var option_ad7c426ceac0469c9c8f8e7b4552288d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u6559\u80b2\u6c34\u5e73",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 225.0
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 53.10314685314686
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 41.302447552447575
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 22.814685314685327
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 16.520979020979023
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 51.13636363636364
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 37.76223776223778
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 38.94230769230768
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 136.49475524475525
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 107.77972027972027
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 64.51048951048949
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 37.76223776223778
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 37.368881118881134
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 26.748251748251743
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 73.95104895104897
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 59.790209790209815
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 61.756993006992985
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 39.335664335664354
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 94.79895104895108
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 25.56818181818182
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 8.260489510489524
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 31.075174825174827
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 60.57692307692311
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 18.487762237762244
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 17.307692307692296
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 14.947552447552454
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 64.90384615384617
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 13.374125874125884
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 0.0
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 3.1468531468531653
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 14.160839160839156
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6559\u80b2\u6c34\u5e73"
#             ],
#             "selected": {
#                 "\u6559\u80b2\u6c34\u5e73": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u6559\u80b2\u6c34\u5e73"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 225,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140
#     }
# };
#                 chart_ad7c426ceac0469c9c8f8e7b4552288d.setOption(option_ad7c426ceac0469c9c8f8e7b4552288d);
#         });
#     </script>

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
region = IN['地区']
x = MinMaxScaler().fit_transform(IN['工业化综合指数'].values.reshape(-1, 1))*225

from pyecharts import options as opts
from pyecharts.charts import Map
c = (
    Map()
    .add("工业指数", [list(z) for z in zip(region, x.ravel())], "china", is_map_symbol_show=False)
    .set_global_opts(title_opts=opts.TitleOpts(title="工业指数"),
    visualmap_opts=opts.VisualMapOpts(max_=225))
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="e42abf301aa34ca6a46cb2a67519da80" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_e42abf301aa34ca6a46cb2a67519da80 = echarts.init(
#                     document.getElementById('e42abf301aa34ca6a46cb2a67519da80'), 'white', {renderer: 'canvas'});
#                 var option_e42abf301aa34ca6a46cb2a67519da80 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5de5\u4e1a\u6307\u6570",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 225.0
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 225.0
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 114.34426229508199
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 66.39344262295081
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 132.78688524590163
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 191.8032786885246
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 132.78688524590163
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 51.63934426229509
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 225.0
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 210.24590163934425
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 213.93442622950818
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 110.65573770491805
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 191.8032786885246
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 114.34426229508199
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 180.7377049180328
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 99.59016393442624
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 136.47540983606558
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 114.34426229508199
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 210.24590163934425
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 70.08196721311475
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 11.06557377049179
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 180.7377049180328
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 92.21311475409836
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 0.0
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 7.377049180327877
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 29.50819672131148
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 110.65573770491805
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 14.754098360655728
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 84.83606557377048
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 70.08196721311475
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 18.44262295081967
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": false,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5de5\u4e1a\u6307\u6570"
#             ],
#             "selected": {
#                 "\u5de5\u4e1a\u6307\u6570": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5de5\u4e1a\u6307\u6570"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 225,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140
#     }
# };
#                 chart_e42abf301aa34ca6a46cb2a67519da80.setOption(option_e42abf301aa34ca6a46cb2a67519da80);
#         });
#     </script>

# %%
from pyecharts.charts import Geo
from pyecharts.globals import GeoType
from pyecharts import options as opts
regions = ['北京','上海','天津','重庆','广州','深圳','杭州','南京','成都','武汉','西安','郑州','厦门']
values = [94, 98, 76, 89, 65, 64, 56, 59, 45, 23, 22, 22, 21]#随便输入的数据
c = (
Geo().add_schema(maptype="china").add(
    "geo", zip(regions, values), type_ = GeoType.EFFECT_SCATTER
).set_series_opts(
    label_opts=opts.LabelOpts(is_show=False)
).set_global_opts(
    visualmap_opts=opts.VisualMapOpts(is_piecewise=True, max_=225),
        title_opts=opts.TitleOpts(title="Geo涟漪图"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="666402bc7267476587b3183a963b0b7b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_666402bc7267476587b3183a963b0b7b = echarts.init(
#                     document.getElementById('666402bc7267476587b3183a963b0b7b'), 'white', {renderer: 'canvas'});
#                 var option_666402bc7267476587b3183a963b0b7b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "name": "geo",
#             "coordinateSystem": "geo",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         94
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         98
#                     ]
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": [
#                         117.200983,
#                         39.084158,
#                         76
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": [
#                         106.551556,
#                         29.563009,
#                         89
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         65
#                     ]
#                 },
#                 {
#                     "name": "\u6df1\u5733",
#                     "value": [
#                         114.07,
#                         22.62,
#                         64
#                     ]
#                 },
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": [
#                         120.19,
#                         30.26,
#                         56
#                     ]
#                 },
#                 {
#                     "name": "\u5357\u4eac",
#                     "value": [
#                         118.78,
#                         32.04,
#                         59
#                     ]
#                 },
#                 {
#                     "name": "\u6210\u90fd",
#                     "value": [
#                         104.06,
#                         30.67,
#                         45
#                     ]
#                 },
#                 {
#                     "name": "\u6b66\u6c49",
#                     "value": [
#                         114.31,
#                         30.52,
#                         23
#                     ]
#                 },
#                 {
#                     "name": "\u897f\u5b89",
#                     "value": [
#                         108.95,
#                         34.27,
#                         22
#                     ]
#                 },
#                 {
#                     "name": "\u90d1\u5dde",
#                     "value": [
#                         113.65,
#                         34.76,
#                         22
#                     ]
#                 },
#                 {
#                     "name": "\u53a6\u95e8",
#                     "value": [
#                         118.1,
#                         24.46,
#                         21
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "geo"
#             ],
#             "selected": {
#                 "geo": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Geo\u6d9f\u6f2a\u56fe"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 225,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14
#     },
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "emphasis": {}
#     }
# };
#                 chart_666402bc7267476587b3183a963b0b7b.setOption(option_666402bc7267476587b3183a963b0b7b);
#         });
#     </script>

# %%
res.head()
# Out:
#     地区   总人口数  老年人口抚养比     老龄化比率      生产总值       人均地区生产总值  医疗条件指数  教育条件指数  \
# 0   北京  17673    14.38  0.112533  30319.98  140211.241878   4.960   10.00
# 1   天津  12794    13.85  0.109182  18809.64  120710.801930   4.960    5.63
# 2   河北  61907    18.43  0.126871  36010.27   47772.220682   4.237    5.33
# 3   山西  30481    13.94  0.103259  16818.11   45328.000000   2.697    4.86
# 4  内蒙古  20781    12.81  0.098484  17289.22   68302.000000   0.200    4.70
#
#    城镇人口比重   男性人数   女性人数  工业化综合指数
# 0   86.50   8781   8892      100
# 1   83.15   6863   5931      100
# 2   56.43  31210  30697       70
# 3   58.41  15593  14888       57
# 4   62.71  10608  10174       75

# %%
data.head(10)
# Out:
#       年龄段    人口总数      男      女
# 1     0-4   67393  35887  31506
# 2     5-9   63322  34279  29043
# 3   10-14   62248  33775  28473
# 4   15-19   58258  31552  26706
# 5   20-24   68050  36085  31965
# 6   25-29   92977  47710  45268
# 7   30-34   93201  46843  46358
# 8   35-39   81886  41517  40370
# 9   40-44   83574  42557  41017
# 10  45-49  102384  52108  50276

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
'''聚类分析, 根据四个指标看出分出四类最合适'''
from sklearn.cluster import KMeans

data = res[['地区', '人均地区生产总值', '医疗条件指数','教育条件指数','工业化综合指数']]
estimator = KMeans(n_clusters=4)
y_pred = estimator.fit_predict(data.iloc[:, 1:])
data['类别'] = pd.Series(y_pred)
Lclass = [int(data.loc[data['地区'] == '西藏', ['类别']].values),
          int(data.loc[data['地区' ]== '内蒙古', ['类别']].values),
          int(data.loc[data['地区'] == '广东', ['类别']].values),
          int(data.loc[data['地区'] == '北京', ['类别']].values)]

'''类别转换为级别'''
data['级别'] = pd.Series([0]*len(data))
data['级别'] = data['类别'].map(lambda x: Lclass.index(x))
data.head()


region = data['地区']
x = MinMaxScaler().fit_transform(data['级别'].values.reshape(-1, 1))*225

from pyecharts import options as opts
from pyecharts.charts import Map
c = (
    Map()
    .add("综合指数", [list(z) for z in zip(region, x.ravel())], "china")
    .set_global_opts(title_opts=opts.TitleOpts(title="综合指数"),
    visualmap_opts=opts.VisualMapOpts(max_=225))
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="e924ee4ddbb74b05b42120d5978535fc" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_e924ee4ddbb74b05b42120d5978535fc = echarts.init(
#                     document.getElementById('e924ee4ddbb74b05b42120d5978535fc'), 'white', {renderer: 'canvas'});
#                 var option_e924ee4ddbb74b05b42120d5978535fc = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u7efc\u5408\u6307\u6570",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 225.0
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 225.0
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 0.0
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 0.0
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 75.0
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 75.0
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 0.0
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 0.0
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 225.0
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 225.0
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 150.0
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 0.0
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 150.0
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 0.0
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 75.0
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 0.0
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 75.0
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 0.0
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 150.0
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 0.0
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 0.0
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 75.0
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 0.0
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 0.0
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 0.0
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 0.0
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 75.0
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 0.0
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 0.0
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 0.0
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 0.0
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7efc\u5408\u6307\u6570"
#             ],
#             "selected": {
#                 "\u7efc\u5408\u6307\u6570": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u7efc\u5408\u6307\u6570"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 225,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140
#     }
# };
#                 chart_e924ee4ddbb74b05b42120d5978535fc.setOption(option_e924ee4ddbb74b05b42120d5978535fc);
#         });
#     </script>

# %%
from pyecharts.charts import Geo
from pyecharts.globals import GeoType
from pyecharts import options as opts
c = (
Geo().add_schema(maptype="china").add(
    "综合指数", zip(region, x.ravel()), type_ = GeoType.EFFECT_SCATTER # "heatmap"
).set_series_opts(
    label_opts=opts.LabelOpts(is_show=False)
).set_global_opts(
    visualmap_opts=opts.VisualMapOpts(is_piecewise=True, max_=225),
        title_opts=opts.TitleOpts(title="综合指数"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="c8d61189a5fe4d25ad2a155572cf0659" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_c8d61189a5fe4d25ad2a155572cf0659 = echarts.init(
#                     document.getElementById('c8d61189a5fe4d25ad2a155572cf0659'), 'white', {renderer: 'canvas'});
#                 var option_c8d61189a5fe4d25ad2a155572cf0659 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "name": "\u7efc\u5408\u6307\u6570",
#             "coordinateSystem": "geo",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         225.0
#                     ]
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": [
#                         117.200983,
#                         39.084158,
#                         225.0
#                     ]
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": [
#                         114.468664,
#                         38.037057,
#                         0.0
#                     ]
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": [
#                         112.562398,
#                         37.873531,
#                         0.0
#                     ]
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": [
#                         111.765617,
#                         40.817498,
#                         75.0
#                     ]
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": [
#                         123.42944,
#                         41.835441,
#                         75.0
#                     ]
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": [
#                         125.32599,
#                         43.896536,
#                         0.0
#                     ]
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": [
#                         126.661669,
#                         45.742347,
#                         0.0
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         225.0
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": [
#                         118.763232,
#                         32.061707,
#                         225.0
#                     ]
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": [
#                         120.152791,
#                         30.267446,
#                         150.0
#                     ]
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": [
#                         117.284922,
#                         31.861184,
#                         0.0
#                     ]
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": [
#                         119.295144,
#                         26.100779,
#                         150.0
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": [
#                         115.909228,
#                         28.675696,
#                         0.0
#                     ]
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": [
#                         117.020359,
#                         36.66853,
#                         75.0
#                     ]
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": [
#                         113.753602,
#                         34.765515,
#                         0.0
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": [
#                         114.341861,
#                         30.546498,
#                         75.0
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": [
#                         112.98381,
#                         28.112444,
#                         0.0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": [
#                         113.26653,
#                         23.132191,
#                         150.0
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": [
#                         108.327546,
#                         22.815478,
#                         0.0
#                     ]
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": [
#                         110.349228,
#                         20.017377,
#                         0.0
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": [
#                         106.551556,
#                         29.563009,
#                         75.0
#                     ]
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": [
#                         104.075931,
#                         30.651651,
#                         0.0
#                     ]
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": [
#                         106.70741,
#                         26.598194,
#                         0.0
#                     ]
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": [
#                         102.710002,
#                         25.045806,
#                         0.0
#                     ]
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": [
#                         91.117212,
#                         29.646922,
#                         0.0
#                     ]
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": [
#                         108.954239,
#                         34.
