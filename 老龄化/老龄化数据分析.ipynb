# %%
# %pylab
# %matplotlib inline 
import pandas as pd
import pyecharts
import seaborn as sns
from matplotlib import patches
from scipy.spatial import ConvexHull
import warnings; warnings.simplefilter('ignore')
sns.set(style='white')
mpl.rcParams['font.sans-serif'] = ['SimHei'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
# df = pd.read_csv('./data/2018各省市年龄与抚养比.csv').drop('Unnamed: 0', axis=1)
# df.to_csv('./data/2018各省市年龄与抚养比.csv', index=False)

# %%
AR = pd.read_csv('./data/2018各省市年龄与抚养比.csv')
GDP = pd.read_csv('./data/2018各省市生产总值.csv')
MT = pd.read_csv('./data/med.csv') # 医疗水平
ED = pd.read_csv('./data/edu.csv') # 教育水平
UAR = pd.read_csv('./data/2010-2018各省市城市人口比重.csv')
SEX = pd.read_csv('./data/2018各省市性别比例.csv')
IN = pd.read_csv('./data/2018各省市工业化水平.csv')
AS = pd.read_csv('./data/2018年龄段性别比例.csv')

# %%
for df in [AR, GDP, MT, ED, UAR, SEX, IN]:
    df['地区'] = df['地区'].apply(lambda city: ''.join(str(city).split('  ')).strip())
#     df.set_index('地区')

# %%
for df in [AR, GDP, MT, ED, UAR, SEX, IN]:
    display(df.head(2))
# Out:
#    地区      人口数   0-14岁  15-64岁     65岁及以上   总抚养比  少年儿童抚养比  老年人口抚养比     老龄化比率
# 0  全国  1144648  192963  815039  136645.26  40.44    23.68    16.77  0.119378
# 1  北京    17673    1850   13834    1988.79  27.75    13.37    14.38  0.112533
#    地区      生产总值  总值第一产业   总值第二产业    总值第三产业       人均地区生产总值  人均总值第一产业  人均总值第二产业  \
# 0  北京  30319.98  118.69  5647.65  24553.64  140211.241878      0.39     18.63
# 1  天津  18809.64  172.71  7609.81  11027.12  120710.801930      0.92     40.46
#
#    人均总值第三产业  地区生产总值指数  第一产业指数  第二产业指数  第三产业指数  人均地区生产总值.1
# 0     80.98     106.6    97.7   104.2   107.3  107.093618
# 1     58.62     103.6   100.1   101.0   105.9  103.710112
#    地区  人口集聚度  基层医疗机构数(张)  卫生机构集聚度  卫生机构比值    床位数(张)  床位数集聚度  床位数比值
# 0  江苏  5.464     29099.0    2.967    0.54   77546.0   5.150   0.95
# 1  山东  4.533     72904.0    4.960    1.11  115017.0   5.096   1.14
#    地区  发展指数2017  发展指数19年版  创新指数2017  创新指数19年版  绿色指数2017  绿色指数19年版  综合指数2017  \
# 0  全国      5.51      5.51      3.31      3.24      8.51      8.59      5.62
# 1  北京     10.00     10.00     10.00     10.00      9.93     10.00     10.00
#
#    综合指数19年版
# 0      5.62
# 1     10.00
#    地区       2010   2011   2012   2013   2014  2015   2016   2017   2018
# 0  全国  49.950000  51.27  52.57  53.73  54.77  56.1  57.35  58.52  59.58
# 1  北京  85.959455  86.20  86.20  86.30  86.35  86.5  86.50  86.50  86.50
#    地区       合计       男       女
# 0  全国  1144648  585299  559349
# 1  北京    17673    8781    8892
#    地区  工业化综合指数
# 0  北京      100
# 1  天津      100

# %%
res = AR.iloc[1:, 0]
for df in [AR[['地区', '人口数', '老年人口抚养比', '老龄化比率']], 
           GDP[['地区', '生产总值', '人均地区生产总值']], 
           MT[['地区', '卫生机构集聚度']], 
           ED[['地区', '综合指数19年版']], 
           UAR[['地区', '2018']], 
           SEX[['地区', '男','女']],
          IN[['地区', '工业化综合指数']]]:
    res = pd.merge(res, df, how='left', on='地区')
res.columns = ['地区', '总人口数', '老年人口抚养比', '老龄化比率', '生产总值', '人均地区生产总值', '医疗条件指数',
       '教育条件指数', '城镇人口比重', '男性人数', '女性人数', '工业化综合指数']
res.fillna(res['医疗条件指数'].max(), inplace=True)
res.head()
# Out:
#     地区   总人口数  老年人口抚养比     老龄化比率      生产总值       人均地区生产总值  医疗条件指数  教育条件指数  \
# 0   北京  17673    14.38  0.112533  30319.98  140211.241878   4.960   10.00
# 1   天津  12794    13.85  0.109182  18809.64  120710.801930   4.960    5.74
# 2   河北  61907    18.43  0.126871  36010.27   47772.220682   4.237    5.11
# 3   山西  30481    13.94  0.103259  16818.11   45328.000000   2.697    4.83
# 4  内蒙古  20781    12.81  0.098484  17289.22   68302.000000   0.200    4.76
#
#    城镇人口比重   男性人数   女性人数  工业化综合指数
# 0   86.50   8781   8892      100
# 1   83.15   6863   5931      100
# 2   56.43  31210  30697       70
# 3   58.41  15593  14888       57
# 4   62.71  10608  10174       75

# %%
'''聚类分析, 根据四个指标看出分出四类最合适'''
from sklearn.cluster import KMeans

data = res[['人均地区生产总值', '医疗条件指数','教育条件指数','工业化综合指数']]

SSE = []  # 存放每次结果的误差平方和
for k in range(1,9):
    estimator = KMeans(n_clusters=k)  # 构造聚类器
    estimator.fit(data)
    SSE.append(estimator.inertia_)
X = range(1,9)
plt.xlabel('k')
plt.ylabel('SSE')
plt.plot(X,SSE,'o-')

# %%
# 聚类可视化
categories = set(y_pred)
colors = [plt.cm.tab10(i/float(len(categories))) for i in range(len(categories))]
plt.figure(figsize=(10, 8), dpi= 80, facecolor='w', edgecolor='k')    
sns.scatterplot(x= '医疗条件指数', y='人均地区生产总值', 
            hue=y_pred, palette="Set2", s=100, alpha=0.5,
            data=data)

# for i, category in enumerate(categories):
#     plt.scatter('医疗条件指数', '人均地区生产总值',  data=data[y_pred == categories],
#                 cmap=colors[i], label=str(category), edgecolors='black', linewidths=.5)

def encircle(x,y, ax=None, **kw):
    if not ax: ax=plt.gca()
    p = np.c_[x,y]
    hull = ConvexHull(p)
    poly = plt.Polygon(p[hull.vertices,:], **kw)
    ax.add_patch(poly)

    

fc = ['red', 'gold', 'blue', 'green']    
def draw_circle(index):
    midwest_encircle_data = data[y_pred == index]                         
    encircle(midwest_encircle_data['医疗条件指数'], midwest_encircle_data['人均地区生产总值'], ec="k", fc=fc[index], alpha=0.1)
    encircle(midwest_encircle_data['医疗条件指数'], midwest_encircle_data['人均地区生产总值'], ec="firebrick", fc="none", linewidth=1.5)

    
# for index in categories:
#     draw_circle(index)
draw_circle(0) 

plt.gca().set(xlim=(0.0, 5.2), ylim=(2000, 145000),
              xlabel='医疗条件指数', ylabel='人均地区生产总值')


plt.xticks(fontsize=12); plt.yticks(fontsize=12)
plt.title("聚类结果", fontsize=22)
plt.legend(fontsize=12)    
plt.show()

# %%
res.corr()['老龄化比率'].to_frame()
# Out:
#              老龄化比率
# 总人口数      0.432813
# 老年人口抚养比   0.976877
# 老龄化比率     1.000000
# 生产总值      0.415584
# 人均地区生产总值  0.286122
# 医疗条件指数    0.560783
# 教育条件指数    0.435469
# 城镇人口比重    0.406100
# 男性人数      0.410160
# 女性人数      0.455762
# 工业化综合指数   0.492345

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(res.corr(), cmap='rainbow')
# Out:
# <AxesSubplot:>

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie
from pyecharts.faker import Faker

value = SEX.iloc[0].values[2:]
value_sum = sum(value)
value = [round(v / value_sum * 10000 / 100, 2) for v in value]
label = ['男', '女']

p = (
    Pie()
    .add("", [list(z) for z in zip(label, value)])
    .set_colors(["green", "red"])
    .set_global_opts(title_opts=opts.TitleOpts(title="男女分布饼图"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    
)
p.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c9f21ef0b89646c8bf090fb047ca4067" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c9f21ef0b89646c8bf090fb047ca4067 = echarts.init(
#                     document.getElementById('c9f21ef0b89646c8bf090fb047ca4067'), 'white', {renderer: 'canvas'});
#                 var option_c9f21ef0b89646c8bf090fb047ca4067 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "green",
#         "red"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u7537",
#                     "value": 51.13
#                 },
#                 {
#                     "name": "\u5973",
#                     "value": 48.87
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7537",
#                 "\u5973"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u7537\u5973\u5206\u5e03\u997c\u56fe"
#         }
#     ]
# };
#                 chart_c9f21ef0b89646c8bf090fb047ca4067.setOption(option_c9f21ef0b89646c8bf090fb047ca4067);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie
from pyecharts.faker import Faker

value = AR.loc[AR['地区']  == '全国', [ '0-14岁', '15-64岁', '65岁及以上']].values.ravel()
value_sum = sum(value)
value = [round(v / value_sum * 10000 / 100, 2) for v in value]
label = [ '0-14岁', '15-64岁', '65岁及以上']

p = (
    Pie()
    .add("", [list(z) for z in zip(label, value)])
    .set_colors(["yellow", "red", "pink"])
    .set_global_opts(title_opts=opts.TitleOpts(title="男女分布饼图"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    
)
p.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="173f2b83b4ed4edd98f9fc7fbde1cd74" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_173f2b83b4ed4edd98f9fc7fbde1cd74 = echarts.init(
#                     document.getElementById('173f2b83b4ed4edd98f9fc7fbde1cd74'), 'white', {renderer: 'canvas'});
#                 var option_173f2b83b4ed4edd98f9fc7fbde1cd74 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "yellow",
#         "red",
#         "pink"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "0-14\u5c81",
#                     "value": 16.86
#                 },
#                 {
#                     "name": "15-64\u5c81",
#                     "value": 71.2
#                 },
#                 {
#                     "name": "65\u5c81\u53ca\u4ee5\u4e0a",
#                     "value": 11.94
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "0-14\u5c81",
#                 "15-64\u5c81",
#                 "65\u5c81\u53ca\u4ee5\u4e0a"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u7537\u5973\u5206\u5e03\u997c\u56fe"
#         }
#     ]
# };
#                 chart_173f2b83b4ed4edd98f9fc7fbde1cd74.setOption(option_173f2b83b4ed4edd98f9fc7fbde1cd74);
#         });
#     </script>

# %%
SEX.head()
# Out:
#    地区       合计       男       女
# 0  全国  1144648  585299  559349
# 1  北京    17673    8781    8892
# 2  天津    12794    6863    5931
# 3  河北    61907   31210   30697
# 4  山西    30481   15593   14888

# %%
data = AR.iloc[0:, [0, 2, 3, 4]]
data = pd.merge(data, SEX.iloc[0:, [0, 2, 3]], on='地区')
data = data.iloc[0, 1:]
M = (data[:-2]  * 1.05 // 2).to_frame().reset_index()
F = (data[:-2] * 0.95 // 2 ).to_frame().reset_index()

data = pd.merge(M, F, on='index')
data.columns = ['年龄段','男', '女']
data
# Out:
#       年龄段       男       女
# 0   0-14岁  101305   91657
# 1  15-64岁  427895  387143
# 2  65岁及以上   71738   64906

# %%
plt.figure(figsize=(8, 6))
X = np.array([1, 2, 3])
plt.subplot(121)
plt.bar(data['年龄段'], data['男'], alpha=0.5, width=0.35, label='男')
plt.subplot(122)
plt.bar(data['年龄段'], data['女'], alpha=0.5, width=0.35, label='女')
plt.legend()
plt.ylabel('人数')
plt.xlabel('年龄段')
plt.show()

# %%
data = AS.iloc[1:]
plt.figure(figsize=(10, 8))
ax = plt.subplot(121)
plt.barh(data['年龄段'], data['男'], alpha=0.5, label='男')
ax.invert_xaxis()
plt.yticks([])
plt.legend()
plt.xlabel('人数')

plt.subplot(122)
plt.barh(data['年龄段'], data['女'], alpha=0.5, label='女', color='red')
plt.legend()
# plt.ylabel('人数')
plt.xlabel('人数')

plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
y = MinMaxScaler().fit_transform(res['老龄化比率'].values.reshape(-1, 1))*225
region = res['地区']

from pyecharts import options as opts
from pyecharts.charts import Map
c = (
    Map()
    .add("老龄化程度", [list(z) for z in zip(region, y.ravel())], "china")
    .set_global_opts(title_opts=opts.TitleOpts(title="老龄化程度"),
    visualmap_opts=opts.VisualMapOpts(max_=225))
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="bc4ada662c034289a9158504478d3588" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_bc4ada662c034289a9158504478d3588 = echarts.init(
#                     document.getElementById('bc4ada662c034289a9158504478d3588'), 'white', {renderer: 'canvas'});
#                 var option_bc4ada662c034289a9158504478d3588 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u8001\u9f84\u5316\u7a0b\u5ea6",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 132.1150508910626
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 124.15476813141456
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 166.18396225625136
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 110.0807223310882
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 98.73545620913914
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 220.55549171340118
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 158.68963405068786
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 154.9350695314441
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 220.0016714987651
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 204.4192129733781
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 173.2703430213345
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 178.41013009101582
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 90.13517655128707
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 96.03322073564112
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 225.0
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 127.4046544557823
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 161.55648957486335
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 161.41446045891482
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 61.068945647724064
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 102.95236521669666
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 59.74664524302905
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 208.5627912153959
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 220.8627720151161
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 134.20518162688617
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 92.24866247369435
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 0.0
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 129.93315028267878
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 133.61325678562773
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 45.149016035634915
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 78.35763258438092
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 34.81471173514847
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8001\u9f84\u5316\u7a0b\u5ea6"
#             ],
#             "selected": {
#                 "\u8001\u9f84\u5316\u7a0b\u5ea6": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u8001\u9f84\u5316\u7a0b\u5ea6"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 225,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140
#     }
# };
#                 chart_bc4ada662c034289a9158504478d3588.setOption(option_bc4ada662c034289a9158504478d3588);
#         });
#     </script>

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
region = GDP['地区']
gdp = MinMaxScaler().fit_transform(GDP['人均地区生产总值'].values.reshape(-1, 1))*225

from pyecharts import options as opts
from pyecharts.charts import Map
c = (
    Map()
    .add("GDP", [list(z) for z in zip(region, gdp.ravel())], "china")
    .set_global_opts(title_opts=opts.TitleOpts(title="GDP"),
    visualmap_opts=opts.VisualMapOpts(max_=225))
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="bab8d9bcda76460f8ae42cce2605f4b2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_bab8d9bcda76460f8ae42cce2605f4b2 = echarts.init(
#                     document.getElementById('bab8d9bcda76460f8ae42cce2605f4b2'), 'white', {renderer: 'canvas'});
#                 var option_bab8d9bcda76460f8ae42cce2605f4b2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "GDP",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 225.0
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 184.70062654721852
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 33.966636304839305
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 28.91543939227006
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 76.39323005602185
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 55.118773422711726
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 50.166005807737776
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 24.671505958733352
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 214.19331195116288
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 173.2467821712965
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 139.09641870419296
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 33.84149150878365
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 123.70827507944678
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 33.26756122347422
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 92.85413326049883
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 38.885120153770465
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 72.90835015333522
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 44.66408650854605
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 113.81913712142384
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 20.98214984978973
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 42.6113214284461
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 71.49691330538208
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 36.26251094511868
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 20.474653913585467
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 11.986534935778572
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 24.9269247243393
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 66.42292471914607
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 0.0
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 33.7955887303443
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 47.03149508433782
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 37.48499528362804
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "GDP"
#             ],
#             "selected": {
#                 "GDP": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "GDP"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 225,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140
#     }
# };
#                 chart_bab8d9bcda76460f8ae42cce2605f4b2.setOption(option_bab8d9bcda76460f8ae42cce2605f4b2);
#         });
#     </script>

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
region = MT['地区']
mt = MinMaxScaler().fit_transform(MT[['卫生机构集聚度', '床位数集聚度']].sum(axis=1).values.reshape(-1, 1))*225

from pyecharts import options as opts
from pyecharts.charts import Map
c = (
    Map()
    .add("医疗条件", [list(z) for z in zip(region, mt.ravel())], "china")
    .set_global_opts(title_opts=opts.TitleOpts(title="医疗条件"),
    visualmap_opts=opts.VisualMapOpts(max_=225))
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="93a847bb1d6b46c6ac49f4ec303a6924" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_93a847bb1d6b46c6ac49f4ec303a6924 = echarts.init(
#                     document.getElementById('93a847bb1d6b46c6ac49f4ec303a6924'), 'white', {renderer: 'canvas'});
#                 var option_93a847bb1d6b46c6ac49f4ec303a6924 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u533b\u7597\u6761\u4ef6",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 181.28944995491435
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 225.0
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 114.6528403967538
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 196.19026149684393
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 104.30568079350765
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 100.36068530207393
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 156.71776375112714
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 141.3435527502254
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 114.76555455365192
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 90.8025247971145
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 91.81695220919748
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 98.331830477908
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 60.978358881875565
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 95.51397655545536
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 71.57348963029756
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 70.80703336339045
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 64.49504057709647
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 77.97565374211
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 40.103697024346246
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 19.837691614066724
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 32.596934174932365
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 17.921550946798913
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 21.370604147880968
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 6.041478809738503
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 3.5843101893597837
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 1.3525698827772767
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 0.0
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u533b\u7597\u6761\u4ef6"
#             ],
#             "selected": {
#                 "\u533b\u7597\u6761\u4ef6": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u533b\u7597\u6761\u4ef6"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 225,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140
#     }
# };
#                 chart_93a847bb1d6b46c6ac49f4ec303a6924.setOption(option_93a847bb1d6b46c6ac49f4ec303a6924);
#         });
#     </script>

# %%
ED.head(10)
# Out:
#     地区  发展指数2017  发展指数19年版  创新指数2017  创新指数19年版  绿色指数2017  绿色指数19年版  综合指数2017  \
# 0   全国      5.51      5.51      3.31      3.24      8.51      8.59      5.62
# 1   北京     10.00     10.00     10.00     10.00      9.93     10.00     10.00
# 2   天津      5.75      5.63      3.39      3.17      8.69      8.97      5.81
# 3   河北      5.24      5.33      2.51      2.30      7.67      7.76      5.10
# 4   山西      4.94      4.86      1.62      1.59      8.40      8.46      4.88
# 5  内蒙古      4.80      4.70      1.77      1.76      8.24      8.37      4.80
# 6   辽宁      5.51      5.58      3.06      2.67      8.79      8.89      5.61
# 7   吉林      5.29      5.24      3.00      2.54      8.58      8.58      5.44
# 8  黑龙江      5.27      5.27      2.80      2.75      8.14      8.25      5.29
# 9   上海      7.57      7.75      5.66      6.28     10.00      9.90      7.63
#
#    综合指数19年版
# 0      5.62
# 1     10.00
# 2      5.74
# 3      5.11
# 4      4.83
# 5      4.76
# 6      5.58
# 7      5.29
# 8      5.29
# 9      7.85

# %%
ED[['综合指数19年版']].describe()
# Out:
#         综合指数19年版
# count  32.000000
# mean    5.611562
# std     1.136679
# min     4.290000
# 25%     4.860000
# 50%     5.380000
# 75%     5.930000
# max    10.000000

# %%
from pyecharts.charts import Geo
from pyecharts.globals import GeoType
from pyecharts import options as opts
regions = ['北京','上海','天津','重庆','广州','深圳','杭州','南京','成都','武汉','西安','郑州','厦门']
values = [94, 98, 76, 89, 65, 64, 56, 59, 45, 23, 22, 22, 21]#随便输入的数据
c = (
Geo().add_schema(maptype="china").add(
    "geo", zip(regions, values), type_ = GeoType.EFFECT_SCATTER
).set_series_opts(
    label_opts=opts.LabelOpts(is_show=False)
).set_global_opts(
    visualmap_opts=opts.VisualMapOpts(is_piecewise=True),
        title_opts=opts.TitleOpts(title="Geo涟漪图"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="1700c64a85ee4f439b50773b260e2c11" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_1700c64a85ee4f439b50773b260e2c11 = echarts.init(
#                     document.getElementById('1700c64a85ee4f439b50773b260e2c11'), 'white', {renderer: 'canvas'});
#                 var option_1700c64a85ee4f439b50773b260e2c11 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "name": "geo",
#             "coordinateSystem": "geo",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         94
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         98
#                     ]
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": [
#                         117.200983,
#                         39.084158,
#                         76
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": [
#                         106.551556,
#                         29.563009,
#                         89
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         65
#                     ]
#                 },
#                 {
#                     "name": "\u6df1\u5733",
#                     "value": [
#                         114.07,
#                         22.62,
#                         64
#                     ]
#                 },
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": [
#                         120.19,
#                         30.26,
#                         56
#                     ]
#                 },
#                 {
#                     "name": "\u5357\u4eac",
#                     "value": [
#                         118.78,
#                         32.04,
#                         59
#                     ]
#                 },
#                 {
#                     "name": "\u6210\u90fd",
#                     "value": [
#                         104.06,
#                         30.67,
#                         45
#                     ]
#                 },
#                 {
#                     "name": "\u6b66\u6c49",
#                     "value": [
#                         114.31,
#                         30.52,
#                         23
#                     ]
#                 },
#                 {
#                     "name": "\u897f\u5b89",
#                     "value": [
#                         108.95,
#                         34.27,
#                         22
#                     ]
#                 },
#                 {
#                     "name": "\u90d1\u5dde",
#                     "value": [
#                         113.65,
#                         34.76,
#                         22
#                     ]
#                 },
#                 {
#                     "name": "\u53a6\u95e8",
#                     "value": [
#                         118.1,
#                         24.46,
#                         21
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "geo"
#             ],
#             "selected": {
#                 "geo": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Geo\u6d9f\u6f2a\u56fe"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14
#     },
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "emphasis": {}
#     }
# };
#                 chart_1700c64a85ee4f439b50773b260e2c11.setOption(option_1700c64a85ee4f439b50773b260e2c11);
#         });
#     </script>

# %%
GDP.describe()
# Out:
#                生产总值       总值第一产业        总值第二产业        总值第三产业       人均地区生产总值  \
# count     31.000000    31.000000     31.000000     31.000000      31.000000
# mean   29506.692258  2088.199016  12139.378065  15279.115177   65253.539915
# std    23905.147349  1422.781058  10624.599611  12653.752468   29121.596804
# min     1477.630000   104.370000    628.370000    719.010000   31336.125161
# 25%    15718.120000   960.707400   5701.595000   7963.920000   47561.699114
# 50%    21984.780000  1967.010000   8328.790000  10656.125300   52948.603524
# 75%    36218.025000  3051.480000  15681.390000  19908.700000   72284.628350
# max    97277.770000  4950.520000  41248.520000  52751.180000  140211.241878
#
#         人均总值第一产业   人均总值第二产业   人均总值第三产业    地区生产总值指数      第一产业指数      第二产业指数  \
# count  31.000000  31.000000  31.000000   31.000000   31.000000   31.000000
# mean    8.658065  39.900000  51.439355  106.906452  103.025806  106.245161
# std     4.761462   7.179021   7.739348    1.349552    2.504791    3.168684
# min     0.320000  18.630000  42.700000  103.600000   93.100000  101.000000
# 25%     6.560000  39.140000  46.365000  106.200000  102.750000  104.250000
# 50%     8.600000  41.830000  49.770000  106.800000  103.400000  105.900000
# 75%    10.510000  44.245000  53.835000  107.900000  104.100000  107.650000
# max    20.700000  49.750000  80.980000  109.100000  106.900000  117.500000
#
#            第三产业指数  人均地区生产总值.1
# count   31.000000   31.000000
# mean   107.958065  106.259793
# std      1.543972    1.186362
# min    104.100000  103.710112
# 25%    107.100000  105.406298
# 50%    108.300000  106.172237
# 75%    109.150000  107.201140
# max    110.300000  108.410592

# %%
GDP[['人均地区生产总值']].describe()
# Out:
#             人均地区生产总值
# count      31.000000
# mean    65253.539915
# std     29121.596804
# min     31336.125161
# 25%     47561.699114
# 50%     52948.603524
# 75%     72284.628350
# max    140211.241878

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts

# V1 版本开始支持链式调用
bar = (
    Bar()
    .add_xaxis(["衬衫", "毛衣", "领带", "裤子", "风衣", "高跟鞋", "袜子"])
    .add_yaxis("商家A", [114, 55, 27, 101, 125, 27, 105])
    .add_yaxis("商家B", [57, 134, 137, 129, 145, 60, 49])
    .set_global_opts(title_opts=opts.TitleOpts(title="某商场销售情况"))
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a06937b1497b417594eefc97e32b2d3c" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a06937b1497b417594eefc97e32b2d3c = echarts.init(
#                     document.getElementById('a06937b1497b417594eefc97e32b2d3c'), 'white', {renderer: 'canvas'});
#                 var option_a06937b1497b417594eefc97e32b2d3c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 114,
#                 55,
#                 27,
#                 101,
#                 125,
#                 27,
#                 105
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 57,
#                 134,
#                 137,
#                 129,
#                 145,
#                 60,
#                 49
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u67d0\u5546\u573a\u9500\u552e\u60c5\u51b5"
#         }
#     ]
# };
#                 chart_a06937b1497b417594eefc97e32b2d3c.setOption(option_a06937b1497b417594eefc97e32b2d3c);
#         });
#     </script>
