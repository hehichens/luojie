# %%
# %pylab
# %matplotlib inline 
import pandas as pd
import pyecharts
import seaborn as sns
sns.set(style='darkgrid')
mpl.rcParams['font.sans-serif'] = ['SimHei'] # 指定默认字体
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
# df = pd.read_csv('./data/2018各省市年龄与抚养比.csv').drop('Unnamed: 0', axis=1)
# df.to_csv('./data/2018各省市年龄与抚养比.csv', index=False)

# %%
pd.read_csv('./data/1949-2018性别城乡分布.csv').head()
# Out:
#    Unnamed: 0    年份  总人口(年末)    男性人口数       男性比重    女性人口数       女性比重  城镇人口数  \
# 0           0  1949    54167  28145.0  51.959680  26022.0  48.040320   5765
# 1           1  1950    55196  28669.0  51.940358  26527.0  48.059642   6169
# 2           2  1951    56300  29231.0  51.920071  27069.0  48.079929   6632
# 3           3  1955    61465  31809.0  51.751403  29656.0  48.248597   8285
# 4           4  1960    66207  34283.0  51.781534  31924.0  48.218466  13073
#
#         城镇比重  乡村人口数       乡村比重
# 0  10.643011  48402  89.356989
# 1  11.176535  49027  88.823465
# 2  11.779751  49668  88.220249
# 3  13.479216  53180  86.520784
# 4  19.745646  53134  80.254354

# %%
AR = pd.read_csv('./data/2018各省市年龄与抚养比.csv')
GDP = pd.read_csv('./data/2018各省市生产总值.csv')
MT = pd.read_csv('./data/med.csv') # 医疗水平
ED = pd.read_csv('./data/edu.csv') # 教育水平
UAR = pd.read_csv('./data/2010-2018各省市城市人口比重.csv')
SEX = pd.read_csv('./data/2018各省市性别比例.csv')
IN = pd.read_csv('./data/2018各省市工业化水平.csv')

# %%
for df in [AR, GDP, MT, ED, UAR, SEX, IN]:
    df['地区'] = df['地区'].apply(lambda city: ''.join(str(city).split('  ')).strip())
#     df.set_index('地区')

# %%
for df in [AR, GDP, MT, ED, UAR, SEX, IN]:
    display(df.head(2))
# Out:
#    地区      人口数   0-14岁  15-64岁     65岁及以上   总抚养比  少年儿童抚养比  老年人口抚养比     老龄化比率
# 0  全国  1144648  192963  815039  136645.26  40.44    23.68    16.77  0.119378
# 1  北京    17673    1850   13834    1988.79  27.75    13.37    14.38  0.112533
#    地区      生产总值  总值第一产业   总值第二产业    总值第三产业       人均地区生产总值  人均总值第一产业  人均总值第二产业  \
# 0  北京  30319.98  118.69  5647.65  24553.64  140211.241878      0.39     18.63
# 1  天津  18809.64  172.71  7609.81  11027.12  120710.801930      0.92     40.46
#
#    人均总值第三产业  地区生产总值指数  第一产业指数  第二产业指数  第三产业指数  人均地区生产总值.1
# 0     80.98     106.6    97.7   104.2   107.3  107.093618
# 1     58.62     103.6   100.1   101.0   105.9  103.710112
#    地区  人口集聚度  基层医疗机构数(张)  卫生机构集聚度  卫生机构比值    床位数(张)  床位数集聚度  床位数比值
# 0  江苏  5.464     29099.0    2.967    0.54   77546.0   5.150   0.95
# 1  山东  4.533     72904.0    4.960    1.11  115017.0   5.096   1.14
#    地区  发展指数2017  发展指数19年版  创新指数2017  创新指数19年版  绿色指数2017  绿色指数19年版  综合指数2017  \
# 0  全国      5.51      5.51      3.31      3.24      8.51      8.59      5.62
# 1  北京     10.00     10.00     10.00     10.00      9.93     10.00     10.00
#
#    综合指数19年版
# 0      5.62
# 1     10.00
#    地区       2010   2011   2012   2013   2014  2015   2016   2017   2018
# 0  全国  49.950000  51.27  52.57  53.73  54.77  56.1  57.35  58.52  59.58
# 1  北京  85.959455  86.20  86.20  86.30  86.35  86.5  86.50  86.50  86.50
#    地区       合计       男       女
# 0  全国  1144648  585299  559349
# 1  北京    17673    8781    8892
#    地区  工业化综合指数
# 0  北京      100
# 1  天津      100

# %%
res = AR.iloc[1:, 0]
for df in [AR[['地区', '人口数', '老年人口抚养比', '老龄化比率']], 
           GDP[['地区', '生产总值', '人均地区生产总值']], 
           MT[['地区', '卫生机构集聚度']], 
           ED[['地区', '综合指数19年版']], 
           UAR[['地区', '2018']], 
           SEX[['地区', '男','女']],
          IN[['地区', '工业化综合指数']]]:
    res = pd.merge(res, df, how='left', on='地区')
res.columns = ['地区', '总人口数', '老年人口抚养比', '老龄化比率', '生产总值', '人均地区生产总值', '医疗条件指数',
       '教育条件指数', '城镇人口比重', '男性人数', '女性人数', '工业化综合指数']
res.fillna(res['医疗条件指数'].max(), inplace=True)
res.head()
# Out:
#     地区   总人口数  老年人口抚养比     老龄化比率      生产总值       人均地区生产总值  医疗条件指数  教育条件指数  \
# 0   北京  17673    14.38  0.112533  30319.98  140211.241878   4.960   10.00
# 1   天津  12794    13.85  0.109182  18809.64  120710.801930   4.960    5.74
# 2   河北  61907    18.43  0.126871  36010.27   47772.220682   4.237    5.11
# 3   山西  30481    13.94  0.103259  16818.11   45328.000000   2.697    4.83
# 4  内蒙古  20781    12.81  0.098484  17289.22   68302.000000   0.200    4.76
#
#    城镇人口比重   男性人数   女性人数  工业化综合指数
# 0   86.50   8781   8892      100
# 1   83.15   6863   5931      100
# 2   56.43  31210  30697       70
# 3   58.41  15593  14888       57
# 4   62.71  10608  10174       75

# %%
from sklearn.cluster import KMeans

data = res[['人均地区生产总值', '医疗条件指数','教育条件指数','工业化综合指数']]

SSE = []  # 存放每次结果的误差平方和
for k in range(1,9):
    estimator = KMeans(n_clusters=k)  # 构造聚类器
    estimator.fit(data)
    SSE.append(estimator.inertia_)
X = range(1,9)
plt.xlabel('k')
plt.ylabel('SSE')
plt.plot(X,SSE,'o-')

# %%
estimator = KMeans(n_clusters=4, random_state=9)
y_pred = estimator.fit_predict(data[['医疗条件指数','人均地区生产总值']])
plt.scatter(data.loc[:, '医疗条件指数'], data.loc[:, '人均地区生产总值'], c=y_pred)

# %%
res.corr()['老龄化比率'].to_frame()
# Out:
#              老龄化比率
# 总人口数      0.432813
# 老年人口抚养比   0.976877
# 老龄化比率     1.000000
# 生产总值      0.415584
# 人均地区生产总值  0.286122
# 医疗条件指数    0.560783
# 教育条件指数    0.435469
# 城镇人口比重    0.406100
# 男性人数      0.410160
# 女性人数      0.455762
# 工业化综合指数   0.492345

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(res.corr(), cmap='rainbow')
# Out:
# <AxesSubplot:>

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie
from pyecharts.faker import Faker

value = SEX.iloc[0].values[2:]
value_sum = sum(value)
value = [round(v / value_sum * 10000 / 100, 2) for v in value]
label = ['男', '女']

p = (
    Pie()
    .add("", [list(z) for z in zip(label, value)])
    .set_colors(["green", "red"])
    .set_global_opts(title_opts=opts.TitleOpts(title="Pie-设置颜色"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    
)
p.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="03d5ab7ee93e4bd2bb60945b36f5a170" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_03d5ab7ee93e4bd2bb60945b36f5a170 = echarts.init(
#                     document.getElementById('03d5ab7ee93e4bd2bb60945b36f5a170'), 'white', {renderer: 'canvas'});
#                 var option_03d5ab7ee93e4bd2bb60945b36f5a170 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "green",
#         "red"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u7537",
#                     "value": 51.13
#                 },
#                 {
#                     "name": "\u5973",
#                     "value": 48.87
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7537",
#                 "\u5973"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Pie-\u8bbe\u7f6e\u989c\u8272"
#         }
#     ]
# };
#                 chart_03d5ab7ee93e4bd2bb60945b36f5a170.setOption(option_03d5ab7ee93e4bd2bb60945b36f5a170);
#         });
#     </script>

# %%
[list(z) for z in zip(['男', '女'], value[1:])]
# Out:
# [['男', 585299], ['女', 559349]]

# %%
AR.loc[AR['地区']  == '全国', [ '0-14岁', '15-64岁', '65岁及以上']].plot.bar()
# Out:
# <AxesSubplot:>

# %%
y = np.round(res['老龄化比率'].values, 4) # 老龄化指数
region = GDP['地区'].values[1:]
from pyecharts import options as opts
from pyecharts.charts import Map
c = (
    Map()
    .add("老龄化程度", [list(z) for z in zip(region, y*1000)], "china")
    .set_global_opts(title_opts=opts.TitleOpts(title="老龄化程度"),
    visualmap_opts=opts.VisualMapOpts(max_=200))
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="a102d06533874121989214a5ee949dea" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_a102d06533874121989214a5ee949dea = echarts.init(
#                     document.getElementById('a102d06533874121989214a5ee949dea'), 'white', {renderer: 'canvas'});
#                 var option_a102d06533874121989214a5ee949dea = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u8001\u9f84\u5316\u7a0b\u5ea6",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 112.5
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 109.2
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 126.9
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 103.3
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 98.5
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 149.79999999999998
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 123.7
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 122.1
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 149.5
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 143.0
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 129.89999999999998
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 132.0
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 94.89999999999999
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 97.3
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 151.60000000000002
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 110.60000000000001
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 124.89999999999999
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 124.89999999999999
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 82.60000000000001
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 100.3
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 82.10000000000001
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 144.7
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 149.9
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 113.4
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 95.8
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 56.9
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 111.60000000000001
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 113.19999999999999
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 75.89999999999999
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 89.89999999999999
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8001\u9f84\u5316\u7a0b\u5ea6"
#             ],
#             "selected": {
#                 "\u8001\u9f84\u5316\u7a0b\u5ea6": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u8001\u9f84\u5316\u7a0b\u5ea6"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 200,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140
#     }
# };
#                 chart_a102d06533874121989214a5ee949dea.setOption(option_a102d06533874121989214a5ee949dea);
#         });
#     </script>

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
region = GDP['地区']
gdp = MinMaxScaler().fit_transform(GDP['人均地区生产总值'].values.reshape(-1, 1))*200

from pyecharts import options as opts
from pyecharts.charts import Map
c = (
    Map()
    .add("GDP", [list(z) for z in zip(region, gdp.ravel())], "china")
    .set_global_opts(title_opts=opts.TitleOpts(title="GDP"),
    visualmap_opts=opts.VisualMapOpts(max_=200))
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="0550639b08664469bffd0d33e6b962c1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_0550639b08664469bffd0d33e6b962c1 = echarts.init(
#                     document.getElementById('0550639b08664469bffd0d33e6b962c1'), 'white', {renderer: 'canvas'});
#                 var option_0550639b08664469bffd0d33e6b962c1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "GDP",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 200.0
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 164.1783347086387
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 30.192565604301603
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 25.702612793128942
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 67.90509338313053
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 48.994465264632645
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 44.59200516243358
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 21.93022751887409
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 190.39405506770035
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 153.99713970781912
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 123.64126107039372
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 30.081325785585467
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 109.96291118173048
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 29.571165531977083
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 82.53700734266562
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 34.56455124779597
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 64.8074223585202
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 39.70141022981871
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 101.17256633015452
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 18.650799866479762
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 37.876730158618756
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 63.552811827006295
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 32.23334306232771
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 18.199692367631528
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 10.654697720692063
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 22.157266421634937
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 59.04259975035207
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 0.0
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 30.0405233158616
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 41.80577340830028
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 33.319995807669365
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "GDP"
#             ],
#             "selected": {
#                 "GDP": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "GDP"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 200,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140
#     }
# };
#                 chart_0550639b08664469bffd0d33e6b962c1.setOption(option_0550639b08664469bffd0d33e6b962c1);
#         });
#     </script>

# %%
MT['比值'] = MT['卫生机构比值'] + MT['床位数比值']

# %%
MT[['比值']].describe()
# Out:
#               比值
# count  27.000000
# mean    2.134444
# std     0.621867
# min     1.220000
# 25%     1.620000
# 50%     2.260000
# 75%     2.360000
# max     4.060000

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
region = MT['地区']
mt = MinMaxScaler().fit_transform(MT['卫生机构集聚度'].values.reshape(-1, 1))*200

from pyecharts import options as opts
from pyecharts.charts import Map
c = (
    Map()
    .add("医疗条件", [list(z) for z in zip(region, mt.ravel())], "china")
    .set_global_opts(title_opts=opts.TitleOpts(title="医疗条件"),
    visualmap_opts=opts.VisualMapOpts(max_=200))
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="974d91407a084975a61c93c5c0d60235" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_974d91407a084975a61c93c5c0d60235 = echarts.init(
#                     document.getElementById('974d91407a084975a61c93c5c0d60235'), 'white', {renderer: 'canvas'});
#                 var option_974d91407a084975a61c93c5c0d60235 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u533b\u7597\u6761\u4ef6",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 118.71941272430671
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 200.0
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 106.8515497553018
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 169.37194127243066
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 122.43066884176184
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 65.74225122349104
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 170.51386623164763
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 115.0489396411093
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 77.36541598694944
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 89.84502446982056
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 96.94127243066886
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 91.72104404567702
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 58.03425774877652
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 107.70799347471454
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 61.174551386623165
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 55.62805872756933
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 68.3115823817292
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 65.61990212071778
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 42.33278955954323
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 23.205546492659053
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 22.634584013050574
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 14.845024469820556
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 21.941272430668842
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 5.872756933115825
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 2.1207177814029374
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 1.2234910277324638
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 0.0
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u533b\u7597\u6761\u4ef6"
#             ],
#             "selected": {
#                 "\u533b\u7597\u6761\u4ef6": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u533b\u7597\u6761\u4ef6"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 200,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140
#     }
# };
#                 chart_974d91407a084975a61c93c5c0d60235.setOption(option_974d91407a084975a61c93c5c0d60235);
#         });
#     </script>

# %%
ED.head(10)
# Out:
#     地区  发展指数2017  发展指数19年版  创新指数2017  创新指数19年版  绿色指数2017  绿色指数19年版  综合指数2017  \
# 0   全国      5.51      5.51      3.31      3.24      8.51      8.59      5.62
# 1   北京     10.00     10.00     10.00     10.00      9.93     10.00     10.00
# 2   天津      5.75      5.63      3.39      3.17      8.69      8.97      5.81
# 3   河北      5.24      5.33      2.51      2.30      7.67      7.76      5.10
# 4   山西      4.94      4.86      1.62      1.59      8.40      8.46      4.88
# 5  内蒙古      4.80      4.70      1.77      1.76      8.24      8.37      4.80
# 6   辽宁      5.51      5.58      3.06      2.67      8.79      8.89      5.61
# 7   吉林      5.29      5.24      3.00      2.54      8.58      8.58      5.44
# 8  黑龙江      5.27      5.27      2.80      2.75      8.14      8.25      5.29
# 9   上海      7.57      7.75      5.66      6.28     10.00      9.90      7.63
#
#    综合指数19年版
# 0      5.62
# 1     10.00
# 2      5.74
# 3      5.11
# 4      4.83
# 5      4.76
# 6      5.58
# 7      5.29
# 8      5.29
# 9      7.85

# %%
ED[['综合指数19年版']].describe()
# Out:
#         综合指数19年版
# count  32.000000
# mean    5.611562
# std     1.136679
# min     4.290000
# 25%     4.860000
# 50%     5.380000
# 75%     5.930000
# max    10.000000

# %%
from pyecharts.charts import Geo
from pyecharts.globals import GeoType
from pyecharts import options as opts
regions = ['北京','上海','天津','重庆','广州','深圳','杭州','南京','成都','武汉','西安','郑州','厦门']
values = [94, 98, 76, 89, 65, 64, 56, 59, 45, 23, 22, 22, 21]#随便输入的数据
c = (
Geo().add_schema(maptype="china").add(
    "geo", zip(regions, values), type_ = GeoType.EFFECT_SCATTER
).set_series_opts(
    label_opts=opts.LabelOpts(is_show=False)
).set_global_opts(
    visualmap_opts=opts.VisualMapOpts(is_piecewise=True),
        title_opts=opts.TitleOpts(title="Geo涟漪图"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="baa7b014719e4e28a1bee1f653fb367d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_baa7b014719e4e28a1bee1f653fb367d = echarts.init(
#                     document.getElementById('baa7b014719e4e28a1bee1f653fb367d'), 'white', {renderer: 'canvas'});
#                 var option_baa7b014719e4e28a1bee1f653fb367d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "name": "geo",
#             "coordinateSystem": "geo",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         94
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         98
#                     ]
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": [
#                         117.200983,
#                         39.084158,
#                         76
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": [
#                         106.551556,
#                         29.563009,
#                         89
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         65
#                     ]
#                 },
#                 {
#                     "name": "\u6df1\u5733",
#                     "value": [
#                         114.07,
#                         22.62,
#                         64
#                     ]
#                 },
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": [
#                         120.19,
#                         30.26,
#                         56
#                     ]
#                 },
#                 {
#                     "name": "\u5357\u4eac",
#                     "value": [
#                         118.78,
#                         32.04,
#                         59
#                     ]
#                 },
#                 {
#                     "name": "\u6210\u90fd",
#                     "value": [
#                         104.06,
#                         30.67,
#                         45
#                     ]
#                 },
#                 {
#                     "name": "\u6b66\u6c49",
#                     "value": [
#                         114.31,
#                         30.52,
#                         23
#                     ]
#                 },
#                 {
#                     "name": "\u897f\u5b89",
#                     "value": [
#                         108.95,
#                         34.27,
#                         22
#                     ]
#                 },
#                 {
#                     "name": "\u90d1\u5dde",
#                     "value": [
#                         113.65,
#                         34.76,
#                         22
#                     ]
#                 },
#                 {
#                     "name": "\u53a6\u95e8",
#                     "value": [
#                         118.1,
#                         24.46,
#                         21
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "geo"
#             ],
#             "selected": {
#                 "geo": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Geo\u6d9f\u6f2a\u56fe"
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14
#     },
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "emphasis": {}
#     }
# };
#                 chart_baa7b014719e4e28a1bee1f653fb367d.setOption(option_baa7b014719e4e28a1bee1f653fb367d);
#         });
#     </script>

# %%
GDP.describe()
# Out:
#                生产总值       总值第一产业        总值第二产业        总值第三产业       人均地区生产总值  \
# count     31.000000    31.000000     31.000000     31.000000      31.000000
# mean   29506.692258  2088.199016  12139.378065  15279.115177   65253.539915
# std    23905.147349  1422.781058  10624.599611  12653.752468   29121.596804
# min     1477.630000   104.370000    628.370000    719.010000   31336.125161
# 25%    15718.120000   960.707400   5701.595000   7963.920000   47561.699114
# 50%    21984.780000  1967.010000   8328.790000  10656.125300   52948.603524
# 75%    36218.025000  3051.480000  15681.390000  19908.700000   72284.628350
# max    97277.770000  4950.520000  41248.520000  52751.180000  140211.241878
#
#         人均总值第一产业   人均总值第二产业   人均总值第三产业    地区生产总值指数      第一产业指数      第二产业指数  \
# count  31.000000  31.000000  31.000000   31.000000   31.000000   31.000000
# mean    8.658065  39.900000  51.439355  106.906452  103.025806  106.245161
# std     4.761462   7.179021   7.739348    1.349552    2.504791    3.168684
# min     0.320000  18.630000  42.700000  103.600000   93.100000  101.000000
# 25%     6.560000  39.140000  46.365000  106.200000  102.750000  104.250000
# 50%     8.600000  41.830000  49.770000  106.800000  103.400000  105.900000
# 75%    10.510000  44.245000  53.835000  107.900000  104.100000  107.650000
# max    20.700000  49.750000  80.980000  109.100000  106.900000  117.500000
#
#            第三产业指数  人均地区生产总值.1
# count   31.000000   31.000000
# mean   107.958065  106.259793
# std      1.543972    1.186362
# min    104.100000  103.710112
# 25%    107.100000  105.406298
# 50%    108.300000  106.172237
# 75%    109.150000  107.201140
# max    110.300000  108.410592

# %%
GDP[['人均地区生产总值']].describe()
# Out:
#             人均地区生产总值
# count      31.000000
# mean    65253.539915
# std     29121.596804
# min     31336.125161
# 25%     47561.699114
# 50%     52948.603524
# 75%     72284.628350
# max    140211.241878

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts

# V1 版本开始支持链式调用
bar = (
    Bar()
    .add_xaxis(["衬衫", "毛衣", "领带", "裤子", "风衣", "高跟鞋", "袜子"])
    .add_yaxis("商家A", [114, 55, 27, 101, 125, 27, 105])
    .add_yaxis("商家B", [57, 134, 137, 129, 145, 60, 49])
    .set_global_opts(title_opts=opts.TitleOpts(title="某商场销售情况"))
)
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="63a5aacdc39c46e18b9fee41b6d421bb" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_63a5aacdc39c46e18b9fee41b6d421bb = echarts.init(
#                     document.getElementById('63a5aacdc39c46e18b9fee41b6d421bb'), 'white', {renderer: 'canvas'});
#                 var option_63a5aacdc39c46e18b9fee41b6d421bb = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "data": [
#                 114,
#                 55,
#                 27,
#                 101,
#                 125,
#                 27,
#                 105
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "data": [
#                 57,
#                 134,
#                 137,
#                 129,
#                 145,
#                 60,
#                 49
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "\u67d0\u5546\u573a\u9500\u552e\u60c5\u51b5"
#         }
#     ]
# };
#                 chart_63a5aacdc39c46e18b9fee41b6d421bb.setOption(option_63a5aacdc39c46e18b9fee41b6d421bb);
#         });
#     </script>
